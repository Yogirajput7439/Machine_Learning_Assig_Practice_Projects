# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# For the following dataset generated using the numpy

data = np.random.normal(loc=70, scale =10, size=200)

# %%
plt.hist(data, bins=10)
plt.title("Histogram Of Scores")
plt.xlabel("X-axis")
plt.ylabel("Y_axis")
mean_value = data.mean()

plt.axvline(x=mean_value, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_value:.2f}')
plt.show()

# %%
penguins = sns.load_dataset("penguins")

# %%
#for the seaborn penguins datasets do some tast...

sns.histplot(
    data=penguins,
    x='body_mass_g',
    y="flipper_length_mm",
    hue="species"
)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
# for the seaborn tips datasets, do the following

tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
marker = ("^" if i == "Yes" else "O" for i in tips["smoker"])

sns.scatterplot(
    data=tips,
    # markers={'Yes': '^', 'No': 'o'},
    style="smoker",
    markers= {'Yes': '^', 'No': 'o'},
    x='total_bill',
    y='tip',
    hue = "sex",
)
plt.title("Total bill vs Tips")
plt.show()
